# %% [markdown]
# <a href="https://colab.research.google.com/github/FranciaAlday/Proyectos/blob/main/PPCienciaDatos/Clases/19SepGraficas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_url = "https://bit.ly/2cLzoxH"
brecha = pd.read_csv(data_url)
brecha.head(n=3)
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710

# %%
brecha["lifeExp"].hist(bins=100)
# Out:
# <Axes: >

# %%
# Se observa que la reducción tan abrupta hace que se pierdan algunos detalles de la distribución,
# con valores grandes se pueden ver más patrones que se ocultan con valores pequeños.
brecha["lifeExp"].hist(bins=10)
# Out:
# <Axes: >

# %%
brecha["lifeExp"].hist(bins=100, grid=False, xlabelsize=12, ylabelsize=12)
plt.title("Hiatograma con pandas", fontsize=16)
plt.xlabel("Esperanza de vida", fontsize=15)
plt.ylabel("Frecuencia", fontsize=15)
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
brecha["gdpPercap"].hist(bins=1000, grid=False)
plt.title("Escala logarítmica", fontsize=16)
plt.xlabel("PIB per cápita", fontsize=15)
plt.ylabel("Frecuencia", fontsize=15)
plt.xscale("log")

# %%
sns.displot(brecha["lifeExp"])

# %%
x1 = np.random.normal(0,0.7,1000)
x2 = np.random.normal(-2,1,1000)
x3 = np.random.normal(3,1.4,1000)
# formato
dic = dict(histype='stepfilled', alpha=0.3, bins=40)
plt.hist(x1,**dic)

# %%
cuenta, bordes = np.histogram(data,bins=5)
print(cuenta)
print(bordes)

# %%
# Bidimensionales. Se dejó de tarea. Pero con un cuadro de 30x30 en ambas dimensiones y decir como se calculan los bordes y el total de elementos en cada cuadrito
mean = [0,0]
cov = [[1,1],[1,2]]
x,y = np.random.multivariate_normal(mean,cov,10000).T
plt.hist2d(x,y, bins=30, cmap='Blues')
cb = plt.colorbar()
cb.set_label("Total por contenedor")

# %%
cuenta, xedges, yedges = np.histogram2d(x,y,bins=5)
cuenta

# %%
print(xedges, yedges)

# %%
# Contenedores hexagonales
plt.hexbin(x,y, gridsize=30, cmap='Blues')
cb = plt.colorbar()
cb.set_label("Total por contenedor")

# %%
data = np.random.multivariate_normal(mean, cov, 10000)
sns.kdeplot(data)
# Out:
# <Axes: ylabel='Density'>
